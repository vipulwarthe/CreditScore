# %% [markdown]
# # **Initial Characteristic Analysis**
# ---

# %% [markdown]
# ### **Characteristic Binning**
#
# Create a function for binning the numerical predictors.

# %%
#import library
import pandas as pd
import numpy as np
import sys
sys.path.append("../src")
#load configuration
import utils

# %%
config_data = utils.config_load()
config_data
# Out:
# {'raw_dataset_path': '../dataset/raw/credit_risk.csv',
#  'dataset_path': '../dataset/output/data.pkl',
#  'predictors_set_path': '../dataset/output/predictors.pkl',
#  'response_set_path': '../dataset/output/response.pkl',
#  'train_path': ['../dataset/output/X_train.pkl',
#   '../dataset/output/y_train.pkl'],
#  'test_path': ['../dataset/output/X_test.pkl', '../dataset/output/y_test.pkl'],
#  'data_train_path': '../dataset/output/training_data.pkl',
#  'data_train_binned_path': '../dataset/output/bin_training_data.pkl',
#  'crosstab_list_path': '../dataset/output/list_crosstab.pkl',
#  'WOE_table_path': '../dataset/output/WOE_table.pkl',
#  'IV_table_path': '../dataset/output/IV_table.pkl',
#  'WOE_map_dict_path': '../dataset/output/WOE_map_dict.pkl',
#  'X_train_woe_path': '../dataset/output/X_train_woe.pkl',
#  'response_variable': 'loan_status',
#  'test_size': 0.2,
#  'num_columns': ['person_age',
#   'person_income',
#   'person_emp_length',
#   'loan_amnt',
#   'loan_int_rate',
#   'loan_percent_income',
#   'cb_person_cred_hist_length'],
#  'cat_columns': ['person_home_ownership',
#   'loan_intent',
#   'cb_person_default_on_file'],
#  'missing_columns': ['person_emp_length_bin', 'loan_int_rate_bin'],
#  'num_of_bins': 5,
#  'penalty': 'l2',
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': '../models/forward_models.pkl',
#  'best_predictors_path': '../models/best_predictors_path.pkl',
#  'best_model_path': '../models/best_model.pkl',
#  'best_model_summary_path': '../models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 200,
#  'odds_ref': 30,
#  'scorecards_path': '../models/scorecards.pkl',
#  'points_map_dict_path': '../models/points_map_dict.pkl',
#  'X_points_path': '../models/X_points.pkl',
#  'X_train_points_path': '../models/X_train_points.pkl',
#  'score_path': '../models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['person_age_bin',
#   'person_income_bin',
#   'person_emp_length_bin',
#   'loan_amnt_bin',
#   'loan_int_rate_bin',
#   'loan_percent_income_bin',
#   'cb_person_cred_hist_length_bin',
#   'person_home_ownership',
#   'loan_intent',
#   'cb_person_default_on_file']}

# %%
#load the training data from a pickled file using the configuration data
data_train = utils.pickle_load(config_data['data_train_path'])

# %%
#display information about the training data
data_train.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15884          25         241875              MORTGAGE                4.0
# 15138          21          18000                  RENT                5.0
# 7474           25          53000              MORTGAGE               10.0
# 18212          28          16800                   OWN                NaN
# 6493           25          50000              MORTGAGE                2.0
#
#       loan_intent  loan_amnt  loan_int_rate  loan_percent_income  \
# 15884   EDUCATION      16000           7.05                 0.07
# 15138    PERSONAL       1500          12.18                 0.08
# 7474      MEDICAL      16000          12.53                 0.30
# 18212     MEDICAL       5000          13.98                 0.30
# 6493      VENTURE      10000           7.90                 0.20
#
#       cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# 15884                         N                           4            0
# 15138                         N                           4            1
# 7474                          N                           2            0
# 18212                         N                           8            1
# 6493                          N                           2            0

# %% [markdown]
# Create a function for binning the numerical predictors

# %%
def create_binning(data, predictor_label, num_of_bins):
    """
    Bin a numerical predictor into the specified number of bins

    Parameters
    ----------
    data : DataFrame
        The DataFrame containing the data
    predictor_label : Str
        The label of the numerical predictor column
    num_of_bins : Int
        The number of bins to create
    
    Returns
    -------
    pd.DataFrame : The DataFrame with a new column containing the binned predictor values
    """
    # create a new column containing the binned predictor
    data[predictor_label + "_bin"] = pd.qcut(data[predictor_label],
                                             q = num_of_bins,
                                             duplicates='drop')
    
    return data

# %%
def bin_data(type):
    """Bin the numerical and missing data"""
    # Load the concatenated data
    data = utils.pickle_load(config_data[f'data_{type}_path'])

    # Bin the numerical columns
    num_columns = config_data['num_columns']
    num_of_bins = config_data['num_of_bins']

    for column in num_columns:
        data_binned = create_binning(data = data,
                                         predictor_label = column,
                                         num_of_bins = num_of_bins)

    # Bin missing values
    missing_columns = config_data['missing_columns']

    for column in missing_columns:
        # Add category 'Missing' to replace the missing values
        data_binned[column] = (data_binned[column]
                                    .cat
                                    .add_categories('Missing'))

        # Replace missing values with category 'Missing'
        data_binned[column].fillna(value = 'Missing',
                                   inplace = True)

    # Validate
    print(f"Original data shape : ", data.shape)
    print(f"Binned data shape  : ", data_binned.shape)

    # Dump binned data
    utils.pickle_dump(data_binned, config_data[f'data_{type}_binned_path'])
        
    return data_binned

# %%
# Check the function
binned_train = bin_data(type='train')
binned_train.T
# Out:
# Original data shape :  (26064, 18)
# Binned data shape  :  (26064, 18)
#                                                15884                15138  \
# person_age                                        25                   21
# person_income                                 241875                18000
# person_home_ownership                       MORTGAGE                 RENT
# person_emp_length                                4.0                  5.0
# loan_intent                                EDUCATION             PERSONAL
# loan_amnt                                      16000                 1500
# loan_int_rate                                   7.05                12.18
# loan_percent_income                             0.07                 0.08
# cb_person_default_on_file                          N                    N
# cb_person_cred_hist_length                         4                    4
# loan_status                                        0                    1
# person_age_bin                          (23.0, 25.0]       (19.999, 23.0]
# person_income_bin               (86000.0, 6000000.0]  (3999.999, 35000.0]
# person_emp_length_bin                     (3.0, 5.0]           (3.0, 5.0]
# loan_amnt_bin                     (14500.0, 35000.0]    (499.999, 4400.0]
# loan_int_rate_bin                      (5.419, 7.51]       (11.86, 13.92]
# loan_percent_income_bin               (-0.001, 0.08]       (-0.001, 0.08]
# cb_person_cred_hist_length_bin            (3.0, 4.0]           (3.0, 4.0]
#
#                                              7474                 18212  \
# person_age                                      25                   28
# person_income                                53000                16800
# person_home_ownership                     MORTGAGE                  OWN
# person_emp_length                             10.0                  NaN
# loan_intent                                MEDICAL              MEDICAL
# loan_amnt                                    16000                 5000
# loan_int_rate                                12.53                13.98
# loan_percent_income                            0.3                  0.3
# cb_person_default_on_file                        N                    N
# cb_person_cred_hist_length                       2                    8
# loan_status                                      0                    1
# person_age_bin                        (23.0, 25.0]         (27.0, 32.0]
# person_income_bin               (48996.0, 63000.0]  (3999.999, 35000.0]
# person_emp_length_bin                 (8.0, 123.0]              Missing
# loan_amnt_bin                   (14500.0, 35000.0]     (4400.0, 6800.0]
# loan_int_rate_bin                   (11.86, 13.92]       (13.92, 22.48]
# loan_percent_income_bin               (0.25, 0.83]         (0.25, 0.83]
# cb_person_cred_hist_length_bin        (1.999, 3.0]           (5.0, 9.0]
#
#                                              6493                22938  \
# person_age                                      25                  31
# person_income                                50000               60000
# person_home_ownership                     MORTGAGE            MORTGAGE
# person_emp_length                              2.0                 2.0
# loan_intent                                VENTURE     HOMEIMPROVEMENT
# loan_amnt                                    10000                9000
# loan_int_rate                                  7.9               12.69
# loan_percent_income                            0.2                0.15
# cb_person_default_on_file                        N                   N
# cb_person_cred_hist_length                       2                   8
# loan_status                                      0                   0
# person_age_bin                        (23.0, 25.0]        (27.0, 32.0]
# person_income_bin               (48996.0, 63000.0]  (48996.0, 63000.0]
# person_emp_length_bin                   (1.0, 3.0]          (1.0, 3.0]
# loan_amnt_bin                    (6800.0, 10000.0]   (6800.0, 10000.0]
# loan_int_rate_bin                    (7.51, 10.25]      (11.86, 13.92]
# loan_percent_income_bin               (0.18, 0.25]        (0.12, 0.18]
# cb_person_cred_hist_length_bin        (1.999, 3.0]          (5.0, 9.0]
#
#                                                13030               20835  \
# person_age                                        23                  29
# person_income                                  87000               42000
# person_home_ownership                       MORTGAGE                RENT
# person_emp_length                                0.0                 0.0
# loan_intent                                EDUCATION     HOMEIMPROVEMENT
# loan_amnt                                      12000                5000
# loan_int_rate                                  12.73               14.96
# loan_percent_income                             0.14                0.12
# cb_person_default_on_file                          Y                   N
# cb_person_cred_hist_length                         2                   9
# loan_status                                        0                   1
# person_age_bin                        (19.999, 23.0]        (27.0, 32.0]
# person_income_bin               (86000.0, 6000000.0]  (35000.0, 48996.0]
# person_emp_length_bin                  (-0.001, 1.0]       (-0.001, 1.0]
# loan_amnt_bin                     (10000.0, 14500.0]    (4400.0, 6800.0]
# loan_int_rate_bin                     (11.86, 13.92]      (13.92, 22.48]
# loan_percent_income_bin                 (0.12, 0.18]        (0.08, 0.12]
# cb_person_cred_hist_length_bin          (1.999, 3.0]          (5.0, 9.0]
#
#                                              5115                 1971   ...  \
# person_age                                      23                   22  ...
# person_income                                57500                24000  ...
# person_home_ownership                         RENT                 RENT  ...
# person_emp_length                              5.0                  0.0  ...
# loan_intent                              EDUCATION             PERSONAL  ...
# loan_amnt                                     9000                 2100  ...
# loan_int_rate                                 6.91                12.21  ...
# loan_percent_income                           0.16                 0.09  ...
# cb_person_default_on_file                        N                    N  ...
# cb_person_cred_hist_length                       2                    2  ...
# loan_status                                      0                    0  ...
# person_age_bin                      (19.999, 23.0]       (19.999, 23.0]  ...
# person_income_bin               (48996.0, 63000.0]  (3999.999, 35000.0]  ...
# person_emp_length_bin                   (3.0, 5.0]        (-0.001, 1.0]  ...
# loan_amnt_bin                    (6800.0, 10000.0]    (499.999, 4400.0]  ...
# loan_int_rate_bin                    (5.419, 7.51]       (11.86, 13.92]  ...
# loan_percent_income_bin               (0.12, 0.18]         (0.08, 0.12]  ...
# cb_person_cred_hist_length_bin        (1.999, 3.0]         (1.999, 3.0]  ...
#
#                                              24380               30751  \
# person_age                                      27                  43
# person_income                                72000               54000
# person_home_ownership                     MORTGAGE                RENT
# person_emp_length                              6.0                 0.0
# loan_intent                              EDUCATION           EDUCATION
# loan_amnt                                     6000                8725
# loan_int_rate                                 5.42                7.29
# loan_percent_income                           0.08                0.16
# cb_person_default_on_file                        N                   N
# cb_person_cred_hist_length                      10                  14
# loan_status                                      0                   0
# person_age_bin                        (25.0, 27.0]       (32.0, 144.0]
# person_income_bin               (63000.0, 86000.0]  (48996.0, 63000.0]
# person_emp_length_bin                   (5.0, 8.0]       (-0.001, 1.0]
# loan_amnt_bin                     (4400.0, 6800.0]   (6800.0, 10000.0]
# loan_int_rate_bin                    (5.419, 7.51]       (5.419, 7.51]
# loan_percent_income_bin             (-0.001, 0.08]        (0.12, 0.18]
# cb_person_cred_hist_length_bin         (9.0, 30.0]         (9.0, 30.0]
#
#                                              31368               1376   \
# person_age                                      37                  22
# person_income                                44196               35100
# person_home_ownership                         RENT                RENT
# person_emp_length                              0.0                 0.0
# loan_intent                                MEDICAL   DEBTCONSOLIDATION
# loan_amnt                                    12400                1000
# loan_int_rate                                11.26               13.98
# loan_percent_income                           0.28                0.03
# cb_person_default_on_file                        N                   N
# cb_person_cred_hist_length                      14                   2
# loan_status                                      0                   0
# person_age_bin                       (32.0, 144.0]      (19.999, 23.0]
# person_income_bin               (35000.0, 48996.0]  (35000.0, 48996.0]
# person_emp_length_bin                (-0.001, 1.0]       (-0.001, 1.0]
# loan_amnt_bin                   (10000.0, 14500.0]   (499.999, 4400.0]
# loan_int_rate_bin                   (10.25, 11.86]      (13.92, 22.48]
# loan_percent_income_bin               (0.25, 0.83]      (-0.001, 0.08]
# cb_person_cred_hist_length_bin         (9.0, 30.0]        (1.999, 3.0]
#
#                                              22095                 14621  \
# person_age                                      32                    25
# person_income                                38000                 98000
# person_home_ownership                         RENT              MORTGAGE
# person_emp_length                              3.0                   9.0
# loan_intent                                VENTURE       HOMEIMPROVEMENT
# loan_amnt                                     6350                 25000
# loan_int_rate                                 5.79                 16.45
# loan_percent_income                           0.17                  0.26
# cb_person_default_on_file                        N                     N
# cb_person_cred_hist_length                       6                     4
# loan_status                                      0                     1
# person_age_bin                        (27.0, 32.0]          (23.0, 25.0]
# person_income_bin               (35000.0, 48996.0]  (86000.0, 6000000.0]
# person_emp_length_bin                   (1.0, 3.0]          (8.0, 123.0]
# loan_amnt_bin                     (4400.0, 6800.0]    (14500.0, 35000.0]
# loan_int_rate_bin                    (5.419, 7.51]        (13.92, 22.48]
# loan_percent_income_bin               (0.12, 0.18]          (0.25, 0.83]
# cb_person_cred_hist_length_bin          (5.0, 9.0]            (3.0, 4.0]
#
#                                              18736                1663   \
# person_age                                      30                   22
# person_income                                65000                20000
# person_home_ownership                         RENT                 RENT
# person_emp_length                              0.0                  7.0
# loan_intent                                MEDICAL            EDUCATION
# loan_amnt                                    16000                 1675
# loan_int_rate                                13.06                 7.74
# loan_percent_income                           0.25                 0.08
# cb_person_default_on_file                        N                    N
# cb_person_cred_hist_length                       8                    3
# loan_status                                      0                    0
# person_age_bin                        (27.0, 32.0]       (19.999, 23.0]
# person_income_bin               (63000.0, 86000.0]  (3999.999, 35000.0]
# person_emp_length_bin                (-0.001, 1.0]           (5.0, 8.0]
# loan_amnt_bin                   (14500.0, 35000.0]    (499.999, 4400.0]
# loan_int_rate_bin                   (11.86, 13.92]        (7.51, 10.25]
# loan_percent_income_bin               (0.18, 0.25]       (-0.001, 0.08]
# cb_person_cred_hist_length_bin          (5.0, 9.0]         (1.999, 3.0]
#
#                                                18257                17068
# person_age                                        29                   23
# person_income                                 110000                30000
# person_home_ownership                           RENT                 RENT
# person_emp_length                                4.0                  8.0
# loan_intent                          HOMEIMPROVEMENT            EDUCATION
# loan_amnt                                      24000                10625
# loan_int_rate                                  18.39                 6.92
# loan_percent_income                             0.22                 0.35
# cb_person_default_on_file                          Y                    N
# cb_person_cred_hist_length                         8                    4
# loan_status                                        0                    1
# person_age_bin                          (27.0, 32.0]       (19.999, 23.0]
# person_income_bin               (86000.0, 6000000.0]  (3999.999, 35000.0]
# person_emp_length_bin                     (3.0, 5.0]           (5.0, 8.0]
# loan_amnt_bin                     (14500.0, 35000.0]   (10000.0, 14500.0]
# loan_int_rate_bin                     (13.92, 22.48]        (5.419, 7.51]
# loan_percent_income_bin                 (0.18, 0.25]         (0.25, 0.83]
# cb_person_cred_hist_length_bin            (5.0, 9.0]           (3.0, 4.0]
#
# [18 rows x 26064 columns]

# %% [markdown]
# ### **WoE and IV**
#
# To assess the strength of each characteristic individually as a predictor of the credit performance. Create a contingency table/crosstab for all predictors: numerical and categorical predictors.

# %%
def create_crosstab_list():
    """Generate the crosstab list (contingency table) for WOE and IV calculation. Only in training data"""
    # load the binned train data
    data_train_binned = utils.pickle_load(config_data['data_train_binned_path'])

    # load the response variable (we will summarize based on the response variable)
    response_variable = config_data['response_variable']

    # iterate over numercial columns
    crosstab_num = []
    num_columns = config_data['num_columns']
    for column in num_columns:
        # Create a contingency table
        crosstab = pd.crosstab(data_train_binned[column + "_bin"],
                               data_train_binned[response_variable],
                               margins = True)

        # Append to the list
        crosstab_num.append(crosstab)

    # iterate over categorical columns
    crosstab_cat = []
    cat_columns = config_data['cat_columns']
    for column in cat_columns:
        # Create a contingency table
        crosstab = pd.crosstab(data_train_binned[column],
                               data_train_binned[response_variable],
                               margins = True)

        # Append to the list
        crosstab_cat.append(crosstab)

    # Put all two in a crosstab_list
    crosstab_list = crosstab_num + crosstab_cat

    # Validate the crosstab_list
    print('number of num bin : ', [bin.shape for bin in crosstab_num])
    print('number of cat bin : ', [bin.shape for bin in crosstab_cat])

    # Dump the result
    utils.pickle_dump(crosstab_list, config_data['crosstab_list_path'])

    return crosstab_list

# %%
# Check the function
crosstab_list = create_crosstab_list()
crosstab_list[0]
# Out:
# number of num bin :  [(6, 3), (6, 3), (7, 3), (6, 3), (7, 3), (6, 3), (6, 3)]
# number of cat bin :  [(5, 3), (7, 3), (3, 3)]
# loan_status         0     1    All
# person_age_bin
# (19.999, 23.0]   5351  1686   7037
# (23.0, 25.0]     4134  1146   5280
# (25.0, 27.0]     2914   774   3688
# (27.0, 32.0]     4425  1141   5566
# (32.0, 144.0]    3554   939   4493
# All             20378  5686  26064

# %%
crosstab_list[9]
# Out:
# loan_status                    0     1    All
# cb_person_default_on_file
# N                          17505  3948  21453
# Y                           2873  1738   4611
# All                        20378  5686  26064

# %%
def WOE_and_IV():
    """Get the WoE and IV"""
    # Load the crosstab list
    crosstab_list = utils.pickle_load(config_data['crosstab_list_path'])

    # Create initial storage for WoE and IV
    WOE_list, IV_list = [], []
    
    # Perform the calculation for all crosstab list
    for crosstab in crosstab_list:
        # Calcualte the WoE and IV
        crosstab['p_good'] = crosstab[0]/crosstab[0]['All']                                 # Calculate % Good
        crosstab['p_bad'] = crosstab[1]/crosstab[1]['All']                                  # Calculate % Bad
        crosstab['WOE'] = np.log(crosstab['p_good']/crosstab['p_bad'])                      # Calculate the WOE
        crosstab['contribution'] = (crosstab['p_good']-crosstab['p_bad'])*crosstab['WOE']   # Calculate the contribution value for IV
        IV = crosstab['contribution'][:-1].sum()                                            # Calculate the IV
        
        # Append to list
        WOE_list.append(crosstab)

        add_IV = {'Characteristic': crosstab.index.name, 
                  'Information Value': IV}
        IV_list.append(add_IV)


    # CREATE WOE TABLE
    # Create initial table to summarize the WOE values
    WOE_table = pd.DataFrame({'Characteristic': [],
                              'Attribute': [],
                              'WOE': []})
    for i in range(len(crosstab_list)):
        # Define crosstab and reset index
        crosstab = crosstab_list[i].reset_index()

        # Save the characteristic name
        char_name = crosstab.columns[0]

        # Only use two columns (Attribute name and its WOE value)
        # Drop the last row (average/total WOE)
        crosstab = crosstab.iloc[:-1, [0,-2]]
        crosstab.columns = ['Attribute', 'WOE']

        # Add the characteristic name in a column
        crosstab['Characteristic'] = char_name

        WOE_table = pd.concat((WOE_table, crosstab), 
                                axis = 0)

        # Reorder the column
        WOE_table.columns = ['Characteristic',
                            'Attribute',
                            'WOE']
    

    # CREATE IV TABLE
    # Create the initial table for IV
    IV_table = pd.DataFrame({'Characteristic': [],
                             'Information Value' : []})
    IV_table = pd.DataFrame(IV_list)

    # Define the predictive power of each characteristic
    strength = []

    # Assign the rule of thumb regarding IV
    for iv in IV_table['Information Value']:
        if iv < 0.02:
            strength.append('Unpredictive')
        elif iv >= 0.02 and iv < 0.1:
            strength.append('Weak')
        elif iv >= 0.1 and iv < 0.3:
            strength.append('Medium')
        else:
            strength.append('Strong')

    # Assign the strength to each characteristic
    IV_table = IV_table.assign(Strength = strength)

    # Sort the table by the IV values
    IV_table = IV_table.sort_values(by='Information Value')
    
    # Validate
    print('WOE table shape : ', WOE_table.shape)
    print('IV table shape  : ', IV_table.shape)

    # Dump data
    utils.pickle_dump(WOE_table, config_data['WOE_table_path'])
    utils.pickle_dump(IV_table, config_data['IV_table_path']) 

    return WOE_table, IV_table

# %%
# Check the function
WOE_table, IV_table = WOE_and_IV()
# Out:
# WOE table shape :  (49, 3)
# IV table shape  :  (10, 3)

# %%
#display WOE table
WOE_table
# Out:
#                    Characteristic             Attribute       WOE
# 0                  person_age_bin        (19.999, 23.0] -0.121524
# 1                  person_age_bin          (23.0, 25.0]  0.006519
# 2                  person_age_bin          (25.0, 27.0]  0.049261
# 3                  person_age_bin          (27.0, 32.0]  0.078916
# 4                  person_age_bin         (32.0, 144.0]  0.054565
# 0               person_income_bin   (3999.999, 35000.0] -1.007237
# 1               person_income_bin    (35000.0, 48996.0] -0.052875
# 2               person_income_bin    (48996.0, 63000.0]  0.175419
# 3               person_income_bin    (63000.0, 86000.0]  0.492046
# 4               person_income_bin  (86000.0, 6000000.0]  1.030836
# 0           person_emp_length_bin         (-0.001, 1.0] -0.309268
# 1           person_emp_length_bin            (1.0, 3.0] -0.086865
# 2           person_emp_length_bin            (3.0, 5.0]  0.115487
# 3           person_emp_length_bin            (5.0, 8.0]  0.235009
# 4           person_emp_length_bin          (8.0, 123.0]  0.321916
# 5           person_emp_length_bin               Missing -0.521681
# 0                   loan_amnt_bin     (499.999, 4400.0]  0.043609
# 1                   loan_amnt_bin      (4400.0, 6800.0]  0.278812
# 2                   loan_amnt_bin     (6800.0, 10000.0]  0.207943
# 3                   loan_amnt_bin    (10000.0, 14500.0] -0.021755
# 4                   loan_amnt_bin    (14500.0, 35000.0] -0.483470
# 0               loan_int_rate_bin         (5.419, 7.51]  1.032338
# 1               loan_int_rate_bin         (7.51, 10.25]  0.600096
# 2               loan_int_rate_bin        (10.25, 11.86]  0.327310
# 3               loan_int_rate_bin        (11.86, 13.92]  0.080689
# 4               loan_int_rate_bin        (13.92, 22.48] -1.283691
# 5               loan_int_rate_bin               Missing  0.034578
# 0         loan_percent_income_bin        (-0.001, 0.08]  0.769938
# 1         loan_percent_income_bin          (0.08, 0.12]  0.682574
# 2         loan_percent_income_bin          (0.12, 0.18]  0.441174
# 3         loan_percent_income_bin          (0.18, 0.25]  0.162202
# 4         loan_percent_income_bin          (0.25, 0.83] -1.401235
# 0  cb_person_cred_hist_length_bin          (1.999, 3.0] -0.072840
# 1  cb_person_cred_hist_length_bin            (3.0, 4.0] -0.004326
# 2  cb_person_cred_hist_length_bin            (4.0, 5.0]  0.109845
# 3  cb_person_cred_hist_length_bin            (5.0, 9.0]  0.064258
# 4  cb_person_cred_hist_length_bin           (9.0, 30.0]  0.045156
# 0           person_home_ownership              MORTGAGE  0.679659
# 1           person_home_ownership                 OTHER -0.549400
# 2           person_home_ownership                   OWN  1.262009
# 3           person_home_ownership                  RENT -0.507538
# 0                     loan_intent     DEBTCONSOLIDATION -0.323396
# 1                     loan_intent             EDUCATION  0.277027
# 2                     loan_intent       HOMEIMPROVEMENT -0.230444
# 3                     loan_intent               MEDICAL -0.272080
# 4                     loan_intent              PERSONAL  0.097897
# 5                     loan_intent               VENTURE  0.469865
# 0       cb_person_default_on_file                     N  0.212829
# 1       cb_person_default_on_file                     Y -0.773827

# %%
#display IV table
IV_table
# Out:
#                    Characteristic  Information Value      Strength
# 6  cb_person_cred_hist_length_bin           0.003927  Unpredictive
# 0                  person_age_bin           0.006276  Unpredictive
# 2           person_emp_length_bin           0.059921          Weak
# 3                   loan_amnt_bin           0.077772          Weak
# 8                     loan_intent           0.088686          Weak
# 9       cb_person_default_on_file           0.162480        Medium
# 7           person_home_ownership           0.389711        Strong
# 1               person_income_bin           0.459059        Strong
# 4               loan_int_rate_bin           0.600325        Strong
# 5         loan_percent_income_bin           0.709054        Strong
